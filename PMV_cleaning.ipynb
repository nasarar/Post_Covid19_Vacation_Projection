# %% [markdown]
# <a href="https://colab.research.google.com/github/nasarar/Post_Covid19_Vacation_Projection/blob/Joseph/PMV_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Step 1: Load the data
covid_19_PMV = pd.read_csv(
    'https://covid.ourworldindata.org/data/owid-covid-data.csv')
covid_19_PMV.head()
# Out:
#   iso_code continent  ... life_expectancy human_development_index
# 0      AFG      Asia  ...           64.83                   0.511
# 1      AFG      Asia  ...           64.83                   0.511
# 2      AFG      Asia  ...           64.83                   0.511
# 3      AFG      Asia  ...           64.83                   0.511
# 4      AFG      Asia  ...           64.83                   0.511
#
# [5 rows x 59 columns]

# %%
covid_19_PMV.shape
# Out:
# (91026, 59)

# %%
pd.options.display.max_columns= 100

# %%
covid_19_PMV.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
#
#    total_cases_per_million  new_cases_per_million  \
# 0                    0.026                  0.026
# ...

# %% [markdown]
# # Info Method

# %%
covid_19_PMV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91026 entries, 0 to 91025
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               91026 non-null  object
#  1   continent                              86699 non-null  object
#  2   location                               91026 non-null  object
#  3   date                                   91026 non-null  object
#  4   total_cases                            88336 non-null  float64
#  5   new_cases                              88335 non-null  float64
#  6   new_cases_smoothed                     87328 non-null  float64
#  7   total_deaths                           78484 non-null  float64
#  8   new_deaths                             78642 non-null  float64
#  9   new_deaths_smoothed                    87328 non-null  float64
# ...

# %% [markdown]
# # Count method

# %%
covid_19_PMV.count()
# Out:
# iso_code                                 91026
# continent                                86699
# location                                 91026
# date                                     91026
# total_cases                              88336
# new_cases                                88335
# new_cases_smoothed                       87328
# total_deaths                             78484
# new_deaths                               78642
# new_deaths_smoothed                      87328
# total_cases_per_million                  87863
# new_cases_per_million                    87862
# new_cases_smoothed_per_million           86860
# total_deaths_per_million                 78024
# new_deaths_per_million                   78182
# new_deaths_smoothed_per_million          86860
# reproduction_rate                        73367
# icu_patients                              9176
# icu_patients_per_million                  9176
# hosp_patients                            11415
# ...

# %%
covid_19_PMV_missing= covid_19_PMV.isna()
covid_19_PMV_missing.head()
# Out:
#    iso_code  continent  location   date  total_cases  new_cases  \
# 0     False      False     False  False        False      False
# 1     False      False     False  False        False      False
# 2     False      False     False  False        False      False
# 3     False      False     False  False        False      False
# 4     False      False     False  False        False      False
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                True          True        True                 True
# 1                True          True        True                 True
# 2                True          True        True                 True
# 3                True          True        True                 True
# 4                True          True        True                 True
#
#    total_cases_per_million  new_cases_per_million  \
# 0                    False                  False
# 1                    False                  False
# ...

# %%
covid_19_PMV_missing.dtypes
# Out:
# iso_code                                 bool
# continent                                bool
# location                                 bool
# date                                     bool
# total_cases                              bool
# new_cases                                bool
# new_cases_smoothed                       bool
# total_deaths                             bool
# new_deaths                               bool
# new_deaths_smoothed                      bool
# total_cases_per_million                  bool
# new_cases_per_million                    bool
# new_cases_smoothed_per_million           bool
# total_deaths_per_million                 bool
# new_deaths_per_million                   bool
# new_deaths_smoothed_per_million          bool
# reproduction_rate                        bool
# icu_patients                             bool
# icu_patients_per_million                 bool
# hosp_patients                            bool
# ...

# %% [markdown]
# # Sum method

# %%
covid_19_PMV_num_missing= covid_19_PMV_missing.sum()
covid_19_PMV_num_missing
# Out:
# iso_code                                     0
# continent                                 4327
# location                                     0
# date                                         0
# total_cases                               2690
# new_cases                                 2691
# new_cases_smoothed                        3698
# total_deaths                             12542
# new_deaths                               12384
# new_deaths_smoothed                       3698
# total_cases_per_million                   3163
# new_cases_per_million                     3164
# new_cases_smoothed_per_million            4166
# total_deaths_per_million                 13002
# new_deaths_per_million                   12844
# new_deaths_smoothed_per_million           4166
# reproduction_rate                        17659
# icu_patients                             81850
# icu_patients_per_million                 81850
# hosp_patients                            79611
# ...

# %%
len(covid_19_PMV)
# Out:
# 91026

# %%
covid_19_PMV_mean= covid_19_PMV_num_missing/len(covid_19_PMV)
covid_19_PMV_mean
# Out:
# iso_code                                 0.000000
# continent                                0.047536
# location                                 0.000000
# date                                     0.000000
# total_cases                              0.029552
# new_cases                                0.029563
# new_cases_smoothed                       0.040626
# total_deaths                             0.137785
# new_deaths                               0.136049
# new_deaths_smoothed                      0.040626
# total_cases_per_million                  0.034748
# new_cases_per_million                    0.034759
# new_cases_smoothed_per_million           0.045767
# total_deaths_per_million                 0.142838
# new_deaths_per_million                   0.141103
# new_deaths_smoothed_per_million          0.045767
# reproduction_rate                        0.194000
# icu_patients                             0.899194
# icu_patients_per_million                 0.899194
# ...

# %%
covid_19_PMV.isna().mean().round(4) * 100
# Out:
# iso_code                                  0.00
# continent                                 4.75
# location                                  0.00
# date                                      0.00
# total_cases                               2.96
# new_cases                                 2.96
# new_cases_smoothed                        4.06
# total_deaths                             13.78
# new_deaths                               13.60
# new_deaths_smoothed                       4.06
# total_cases_per_million                   3.47
# new_cases_per_million                     3.48
# new_cases_smoothed_per_million            4.58
# total_deaths_per_million                 14.28
# new_deaths_per_million                   14.11
# new_deaths_smoothed_per_million           4.58
# reproduction_rate                        19.40
# icu_patients                             89.92
# icu_patients_per_million                 89.92
# hosp_patients                            87.46
# ...

# %%
covid_19_filtered= covid_19_PMV[['location','date','people_vaccinated','people_fully_vaccinated','population','population_density','gdp_per_capita']]
covid_19_filtered
# Out:
#           location        date  people_vaccinated  people_fully_vaccinated  \
# 0      Afghanistan  2020-02-24                NaN                      NaN
# 1      Afghanistan  2020-02-25                NaN                      NaN
# 2      Afghanistan  2020-02-26                NaN                      NaN
# 3      Afghanistan  2020-02-27                NaN                      NaN
# 4      Afghanistan  2020-02-28                NaN                      NaN
# ...            ...         ...                ...                      ...
# 91021     Zimbabwe  2021-05-20           615296.0                 252100.0
# 91022     Zimbabwe  2021-05-21           624665.0                 263263.0
# 91023     Zimbabwe  2021-05-22           630348.0                 273725.0
# 91024     Zimbabwe  2021-05-23           632496.0                 278537.0
# 91025     Zimbabwe  2021-05-24           633635.0                 281286.0
#
#        population  population_density  gdp_per_capita
# ...

# %%
covid_19_filtered.dropna(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
covid_19_counts= covid_19_filtered["location"].value_counts()
covid_19_counts
# Out:
# World        149
# Germany      149
# Belgium      146
# Israel       141
# Canada       139
#             ...
# Uganda         1
# Mauritius      1
# Bahamas        1
# Australia      1
# Djibouti       1
# Name: location, Length: 149, dtype: int64

# %%
covid_19_counts[covid_19_counts>1].index
# Out:
# Index(['World', 'Germany', 'Belgium', 'Israel', 'Canada', 'Slovenia',
#        'United Kingdom', 'Denmark', 'Estonia', 'Norway',
#        ...
#        'Antigua and Barbuda', 'Jamaica', 'Kyrgyzstan', 'Brunei', 'Mauritania',
#        'Mozambique', 'Congo', 'Senegal', 'Mali', 'Bosnia and Herzegovina'],
#       dtype='object', length=138)

# %%
covid_19_filtered2=covid_19_filtered["location"].isin(covid_19_counts[covid_19_counts>1].index)
covid_19_filtered2
# Out:
# 442      True
# 451      True
# 455      True
# 1266     True
# 1273     True
#          ...
# 91021    True
# 91022    True
# 91023    True
# 91024    True
# 91025    True
# Name: location, Length: 7350, dtype: bool

# %%
covid_19_filter= covid_19_filtered[covid_19_filtered2]
covid_19_filter
# Out:
#           location        date  people_vaccinated  people_fully_vaccinated  \
# 442    Afghanistan  2021-05-11           448878.0                  55624.0
# 451    Afghanistan  2021-05-20           470341.0                  77560.0
# 455    Afghanistan  2021-05-24           476367.0                  96910.0
# 1266       Albania  2021-02-02              549.0                      1.0
# 1273       Albania  2021-02-09              689.0                    438.0
# ...            ...         ...                ...                      ...
# 91021     Zimbabwe  2021-05-20           615296.0                 252100.0
# 91022     Zimbabwe  2021-05-21           624665.0                 263263.0
# 91023     Zimbabwe  2021-05-22           630348.0                 273725.0
# 91024     Zimbabwe  2021-05-23           632496.0                 278537.0
# 91025     Zimbabwe  2021-05-24           633635.0                 281286.0
#
#        population  population_density  gdp_per_capita
# ...

# %%
covid_19_filter['location'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Angola', 'Antigua and Barbuda',
#        'Argentina', 'Aruba', 'Austria', 'Azerbaijan', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize',
#        'Bermuda', 'Bolivia', 'Bosnia and Herzegovina', 'Brazil', 'Brunei',
#        'Bulgaria', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Chile', 'Colombia', 'Comoros', 'Congo',
#        'Costa Rica', 'Croatia', 'Cyprus', 'Czechia', 'Denmark',
#        'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Estonia', 'Finland', 'France',
#        'Gabon', 'Georgia', 'Germany', 'Greece', 'Grenada', 'Guatemala',
#        'Guinea', 'Guyana', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland',
#        'India', 'Indonesia', 'Iran', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kuwait', 'Kyrgyzstan',
#        'Laos', 'Latvia', 'Lebanon', 'Lithuania', 'Luxembourg', 'Macao',
# ...

# %%
covid_19_final=covid_19_filter[covid_19_filter.location != 'World']
covid_19_final
# Out:
#           location        date  people_vaccinated  people_fully_vaccinated  \
# 442    Afghanistan  2021-05-11           448878.0                  55624.0
# 451    Afghanistan  2021-05-20           470341.0                  77560.0
# 455    Afghanistan  2021-05-24           476367.0                  96910.0
# 1266       Albania  2021-02-02              549.0                      1.0
# 1273       Albania  2021-02-09              689.0                    438.0
# ...            ...         ...                ...                      ...
# 91021     Zimbabwe  2021-05-20           615296.0                 252100.0
# 91022     Zimbabwe  2021-05-21           624665.0                 263263.0
# 91023     Zimbabwe  2021-05-22           630348.0                 273725.0
# 91024     Zimbabwe  2021-05-23           632496.0                 278537.0
# 91025     Zimbabwe  2021-05-24           633635.0                 281286.0
#
#        population  population_density  gdp_per_capita
# ...

# %%
covid_19_final['location'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Angola', 'Antigua and Barbuda',
#        'Argentina', 'Aruba', 'Austria', 'Azerbaijan', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize',
#        'Bermuda', 'Bolivia', 'Bosnia and Herzegovina', 'Brazil', 'Brunei',
#        'Bulgaria', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Chile', 'Colombia', 'Comoros', 'Congo',
#        'Costa Rica', 'Croatia', 'Cyprus', 'Czechia', 'Denmark',
#        'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Estonia', 'Finland', 'France',
#        'Gabon', 'Georgia', 'Germany', 'Greece', 'Grenada', 'Guatemala',
#        'Guinea', 'Guyana', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland',
#        'India', 'Indonesia', 'Iran', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kuwait', 'Kyrgyzstan',
#        'Laos', 'Latvia', 'Lebanon', 'Lithuania', 'Luxembourg', 'Macao',
# ...

# %%
covid_19_final.to_csv('covid_19_ready_PMV.csv')
